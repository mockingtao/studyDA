# %%
'''
【项目01】  商铺数据加载及存储

1、成功读取“商铺数据.csv”文件
2、解析数据，存成列表字典格式：[{'var1':value1,'var2':value2,'var3':values,...},...,{}]
3、数据清洗：
① comment，price两个字段清洗成数字
② 清除字段缺失的数据
③ commentlist拆分成三个字段，并且清洗成数字
4、结果存为.pkl文件
'''
# Out:
# "\n【项目01】  商铺数据加载及存储\n\n1、成功读取“商铺数据.csv”文件\n2、解析数据，存成列表字典格式：[{'var1':value1,'var2':value2,'var3':values,...},...,{}]\n3、数据清洗：\n① comment，price两个字段清洗成数字\n② 清除字段缺失的数据\n③ commentlist拆分成三个字段，并且清洗成数字\n4、结果存为.pkl文件\n"

# %%
path = '/Users/matao/Study/data_Analyst/data_ch02_1/商铺数据.csv'
f = open(path, 'r',encoding='utf8')
f.seek(0)
final_data = []

def clean_comment(s):
    if '条' in s:
        return int(s.split(' ')[0])
    else:
        return '无效数据' 
    
def clean_price(s):
    if '￥' in s:
        return int(s.split('￥')[-1])
    else:
        return '无效数据'
    
def clean_commentlist(s):
    if '\n' in s:
        return('无效数据')
    else:
        taste = float(s[0][2:])
        enviroment = float(s[1][2:])
        service = float(s[2][2:5])
        return([taste, enviroment, service])
        
    
for line in f.readlines()[1:]:
    data = line.split(',')
    classify = data[0]
    name = data[1]
    comment = clean_comment(data[2])
    star = data[3]
    price = clean_price(data[4])
    address = data[5]
    commentlist = clean_commentlist(data[-1].split('                                '))
    taste = commentlist[0]
    enviroment = commentlist[1]
    service = commentlist[2]
    if '无效数据' not in [comment,price,commentlist]:
        final_data2 = [["classify", classify], 
                    ["name",name], 
                    ["comment", comment],
                    ["star",star],
                    ["price", price],
                    ["address",address],
                    ["taste",taste],
                    ["enviroment",enviroment],
                    ["service",service]]
        final_data.append(dict(final_data2))
        #print(dict(final_data2))
    else:
        continue
    
print(final_data)
# Out:
# [{'classify': '美食', 'name': '泰国街边料理', 'comment': 74, 'star': '准四星商户', 'price': 48, 'address': '黄兴路合生汇B2美食集市内', 'taste': 7.4, 'enviroment': 7.6, 'service': 7.4}, {'classify': '美食', 'name': '壹面如故(苏宁生活广场店)', 'comment': 265, 'star': '准四星商户', 'price': 21, 'address': '邯郸路585号苏宁生活广场B1层', 'taste': 7.0, 'enviroment': 7.2, 'service': 7.2}, {'classify': '美食', 'name': '鮨谷•Aburiya(合生汇店)', 'comment': 2748, 'star': '准五星商户', 'price': 142, 'address': '翔殷路1099号合生广场5楼23、28铺位', 'taste': 8.9, 'enviroment': 8.5, 'service': 8.4}, {'classify': '美食', 'name': '麦当劳(万达店)', 'comment': 785, 'star': '准四星商户', 'price': 24, 'address': '邯郸路600号万达商业广场B1楼A05号铺', 'taste': 7.4, 'enviroment': 7.2, 'service': 7.2}, {'classify': '美食', 'name': '蒸年青STEAMYOUNG(百联又一城购物中心店)', 'comment': 3779, 'star': '准五星商户', 'price': 70, 'address': '淞沪路8号百联又一城购物中心7层', 'taste': 8.6, 'enviroment': 8.6, 'service': 8.6}, {'classify': '美食', 'name': '丸来玩趣(百联又一城购物中心店)', 'comment': 458, 'star': '准四星商户', 'price': 14, 'address': '淞沪路8号百联又一城购物中心B1层', 'taste': 7.0, 'enviroment': 6.5, 'service': 6.5}, {'classify': '美食', 'name': '韩国雪冰(合生汇店)', 'comment': 1280, 'star': '四星商户', 'price': 47, 'address': '翔殷路1099号合生汇4F', 'taste': 7.7, 'enviroment': 7.5, 'service': 7.6}, {'classify': '美食', 'name': '小菜园新徽菜(五角场万达广场店)', 'comment': 85, 'star': '准五星商户', 'price': 81, 'address': '邯郸路600号万达商业广场特力时尚汇3层', 'taste': 8.5, 'enviroment': 8.9, 'service': 9.0}, {'classify': '美食', 'name': '阿满鸡排(合生汇店)', 'comment': 30, 'star': '四星商户', 'price': 17, 'address': '翔殷路1099号合生汇4层', 'taste': 7.9, 'enviroment': 8.0, 'service': 7.7}, {'classify': '美食', 'name': '莆田餐厅(百联又一城购物中心店)', 'comment': 988, 'star': '四星商户', 'price': 150, 'address': '淞沪路8号百联又一城购物中心7层', 'taste': 8.0, 'enviroment': 8.4, 'service': 8.0}, {'classify': '美食', 'name': '旬彩(百联又一城购物中心店)', 'comment': 152, 'star': '准四星商户', 'price': 16, 'address': '淞沪路8号百联又一城购物中心B1层', 'taste': 7.2, 'enviroment': 7.1, 'service': 7.2}, {'classify': '美食', 'name': '吴茂兴本帮面(五角场店)', 'comment': 72, 'star': '准四星商户', 'price': 21, 'address': '政旦东路34号', 'taste': 7.4, 'enviroment': 7.4, 'service': 7.6}, {'classify': '美食', 'name': '雀舞云南菜(合生汇店)', 'comment': 3627, 'star': '四星商户', 'price': 99, 'address': '翔殷路1099号合生汇5F', 'taste': 8.0, 'enviroment': 8.5, 'service': 8.6}, {'classify': '美食', 'name': '阳光客(城市集市合生汇店)', 'comment': 336, 'star': '准四星商户', 'price': 79, 'address': '黄兴路2228号合生汇B2层城市集市C8商户', 'taste': 7.1, 'enviroment': 7.6, 'service': 7.7}, {'classify': '美食', 'name': '越打星YuetDaSing(合生汇店)', 'comment': 264, 'star': '四星商户', 'price': 48, 'address': '翔殷路1099号合生汇B2城市集市C9', 'taste': 8.0, 'enviroment': 7.7, 'service': 7.8}, {'classify': '美食', 'name': 'MAKA MAKA玛卡玛卡滋蛋仔(五角场店)', 'comment': 67, 'star': '四星商户', 'price': 26, 'address': '邯郸路399号D15-1号', 'taste': 8.2, 'enviroment': 8.4, 'service': 8.4}, {'classify': '美食', 'name': '城市集市(合生汇店)', 'comment': 226, 'star': '准五星商户', 'price': 47, 'address': '黄兴路2228号合生汇B2层城市集市', 'taste': 8.4, 'enviroment': 8.5, 'service': 8.2}, {'classify': '美食', 'name': '许留山(合生汇店)', 'comment': 375, 'star': '三星商户', 'price': 35, 'address': '翔殷路1099号合生汇4F', 'taste': 6.9, 'enviroment': 7.2, 'service': 6.5}, {'classify': '美食', 'name': '汉蒸坊蒸汽海鲜主题餐厅(合生汇店)', 'comment': 830, 'star': '四星商户', 'price': 165, 'address': '翔殷路1099号合生汇5F', 'taste': 7.9, 'enviroment': 7.7, 'service': 7.9}, {'classify': '美食', 'name': '千里香馄饨面', 'comment': 15, 'star': '准四星商户', 'price': 14, 'address': '国定路125号', 'taste': 7.2, 'enviroment': 7.1, 'service': 7.1}, {'classify': '美食', 'name': '星巴克(又一城店)', 'comment': 1113, 'star': '四星商户', 'price': 36, 'address': '淞沪路8号', 'taste': 7.6, 'enviroment': 7.4, 'service': 7.4}, {'classify': '美食', 'name': '百武西茶饮(合生汇店)', 'comment': 33, 'star': '准四星商户', 'price': 18, 'address': '翔殷路1099号合生汇4层', 'taste': 6.9, 'enviroment': 7.2, 'service': 7.1}, {'classify': '休闲娱乐', 'name': '梦想空间Dream Space影吧(五角场店)', 'comment': 957, 'star': '五星商户', 'price': 106, 'address': '政旦东路36号4楼国济路口', 'taste': 9.3, 'enviroment': 9.2, 'service': 9.1}, {'classify': '休闲娱乐', 'name': '快乐菲莉HappyFeelingDIY烘焙(合生汇店)', 'comment': 174, 'star': '五星商 ...
